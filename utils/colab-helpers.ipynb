# %%
# import kagglehub
# if kagglehub.__version__ != "1.0.0": !pip install -Uq kagglehub==1.0.0

# %%
# import os, shutil, kagglehub

# if not os.path.exists("/content/.dataset_ready"):
#     path = kagglehub.competition_download('jan-2026-dl-gen-ai-project')
#     shutil.move(path, "/content/dataset")
#     open("/content/.dataset_ready", "w").close()
